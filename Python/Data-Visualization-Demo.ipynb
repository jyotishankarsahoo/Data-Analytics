# %% [markdown]
# ## Data Loading

# %% [markdown]
# ### Import Required Libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### Mount Google Drive

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Load Data From CSV File

# %%
auto_mobile_data = pd.read_csv("/content/drive/My Drive/DataAnalytics/Data/Automobile.csv")

# %% [markdown]
# **Print 3 Rows From Top**

# %% [markdown]
# ## Data Analysis

# %%
auto_mobile_data.head(3)
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
#
#    peak_rpm city_mpg  highway_mpg  price
# 0      5000       21           27  13495
# ...

# %% [markdown]
# **Print 3 Rows From Bottom**

# %%
auto_mobile_data.tail(3)
# Out:
#      symboling  normalized_losses   make fuel_type aspiration number_of_doors  \
# 198         -1                 95  volvo       gas        std            four
# 199         -1                 95  volvo    diesel      turbo            four
# 200         -1                 95  volvo       gas      turbo            four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 198      sedan          rwd           front       109.1  ...          173
# 199      sedan          rwd           front       109.1  ...          145
# 200      sedan          rwd           front       109.1  ...          141
#
#      fuel_system  bore  stroke compression_ratio horsepower  peak_rpm  \
# 198         mpfi  3.58    2.87               8.8        134      5500
# 199          idi  3.01    3.40              23.0        106      4800
# 200         mpfi  3.78    3.15               9.5        114      5400
#
#     city_mpg  highway_mpg  price
# 198       18           23  21485
# ...

# %% [markdown]
# **How Many Rows and Columns Are In the Data Set**

# %%
print(f"Number Of Rows: {auto_mobile_data.shape[0]}")
print(f"Number Of Columns: {auto_mobile_data.shape[1]}")
# Out:
# Number Of Rows: 201
# Number Of Columns: 26

# %% [markdown]
# **Gather More Data Info and Overal Staticstis**

# %%
auto_mobile_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   symboling            201 non-null    int64
#  1   normalized_losses    201 non-null    int64
#  2   make                 201 non-null    object
#  3   fuel_type            201 non-null    object
#  4   aspiration           201 non-null    object
#  5   number_of_doors      201 non-null    object
#  6   body_style           201 non-null    object
#  7   drive_wheels         201 non-null    object
#  8   engine_location      201 non-null    object
#  9   wheel_base           201 non-null    float64
#  10  length               201 non-null    float64
#  11  width                201 non-null    float64
#  12  height               201 non-null    float64
#  13  curb_weight          201 non-null    int64
#  14  engine_type          201 non-null    object
# ...

# %%
auto_mobile_data.describe(include= "all").T
# Out:
#                      count unique     top freq          mean          std  \
# symboling            201.0    NaN     NaN  NaN      0.840796     1.254802
# normalized_losses    201.0    NaN     NaN  NaN    125.189055    33.572966
# make                   201     22  toyota   32           NaN          NaN
# fuel_type              201      2     gas  181           NaN          NaN
# aspiration             201      2     std  165           NaN          NaN
# number_of_doors        201      2    four  114           NaN          NaN
# body_style             201      5   sedan   94           NaN          NaN
# drive_wheels           201      3     fwd  118           NaN          NaN
# engine_location        201      2   front  198           NaN          NaN
# wheel_base           201.0    NaN     NaN  NaN     98.797015     6.066366
# length               201.0    NaN     NaN  NaN    174.200995    12.322175
# width                201.0    NaN     NaN  NaN     65.889055     2.101471
# ...

# %% [markdown]
# - The Car Price Ranges From 5118 to 45400 Unit
# - The car Weight ranges From 1488 to 4066 units.
# - The Most Common Car make in data is Toyota

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Histogram - (Distribution Of Individual Varibale)

# %% [markdown]
# **Histogram Of Price**

# %%
sns.histplot(data= auto_mobile_data,
             x="price");

# %% [markdown]
# **Customize Histogram**

# %%
plt.title("Histogram:Price")
plt.xlim(3000, 50000)
plt.ylim(0, 70)
plt.xlabel("Price Of Car")
plt.ylabel("Frequency")
sns.histplot(data= auto_mobile_data,
             x="price",
             color="Orange");

# %% [markdown]
# **Customize Bins**

# %%
sns.histplot(data= auto_mobile_data,
             x="price",
             bins= 5,
             color="Orange");

# %%
sns.histplot(data= auto_mobile_data,
             x="price",
             binwidth= 1000,
             color="Orange");

# %% [markdown]
# **Calculate Optimal Bin Width**

# %%
# bin_width = 2 * IQR / Cuberoot(n)
# bins = Range / Bandwidth

# %% [markdown]
# **Kernel Density Estimation** (KDE)

# %%
sns.histplot(data= auto_mobile_data,
             x="price",
             kde=True);

# %% [markdown]
# **Check Histogram For Few More Attributes**

# %%
sns.histplot(data= auto_mobile_data,
             x="curb_weight",
             kde=True);

# %%
sns.histplot(data= auto_mobile_data,
             x="horsepower",
             kde=True);

# %% [markdown]
# **Comparing distribution vs several groups**

# %%
sns.histplot(data= auto_mobile_data,
             x = "price",
             hue = "body_style",
             kde= True);

# %% [markdown]
# **Sublots**

# %%
g = sns.FacetGrid(data= auto_mobile_data,
                  col="body_style")
g.map(sns.histplot,
      "price",
      kde=True);

# %% [markdown]
# ### Box Plot

# %%
sns.boxplot(data= auto_mobile_data,
            x= "curb_weight");

# %% [markdown]
# **Customize Box Plot**

# %%
plt.title("Boxplot:Horsepower")
plt.xlim(30,300)
plt.xlabel("Horsepower")
sns.axes_style("whitegrid")
sns.boxplot(data= auto_mobile_data,
            x = "horsepower",
            color= "cyan");

# %%
sns.boxplot(data= auto_mobile_data,
            x = "body_style",
            y = "price");

# %% [markdown]
# ### Bar Plot (Count Plot For Categorical Data)

# %%
sns.countplot(data=auto_mobile_data,
              x="body_style");

# %%
sns.countplot(data=auto_mobile_data,
              x="body_style",
              hue="fuel_type");

# %% [markdown]
# **Customize Bar Plot**

# %%
plt.figure(figsize=(20,5))
plt.xticks(rotation=90)
sns.countplot(data=auto_mobile_data,
              x="make");

# %% [markdown]
# ### Line Plot (Sesonality Or Trend Of Data Over Time)

# %%
flights_data_set = sns.load_dataset("flights")
sns.lineplot(data= flights_data_set,
             x= "month",
             y= "passengers");
# Shade is Confidence interval
# Solid line is avg value

# %%
plt.figure(figsize=(15,5))
sns.lineplot(data= flights_data_set,
             x= "month",
             y= "passengers",
             errorbar=('ci', False),
             hue = "year")
plt.legend(bbox_to_anchor=[1,1])
plt.ylabel("No Of Passnager");

# %%
fmri = sns.load_dataset("fmri")
sns.lineplot(data= fmri,
             x= "timepoint",
             y= "signal",
             errorbar=('ci', False),
             hue = "region",
             style="region");

# %%
fmri = sns.load_dataset("fmri")
sns.lineplot(data= fmri,
             x= "timepoint",
             y= "signal",
             errorbar=('ci', False),
             hue = "region",
             style="region",
             markers= True);

# %% [markdown]
# ### Scatter Plot (Expresses the extent to which 2 varibales changes togather at constant rate)

# %%
sns.scatterplot(data= auto_mobile_data, x= "engine_size", y = "horsepower");

# %% [markdown]
# **Relationship b/w 2 varibales for diff category**

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(data= auto_mobile_data,
                x= "engine_size",
                y = "horsepower",
                hue="fuel_type",
                style= "fuel_type");

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(data= auto_mobile_data, x= "curb_weight", y = "engine_size");

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(data= auto_mobile_data, x= "bore", y = "stroke");

# %% [markdown]
# ### LMPlot (Best Fit Line)

# %%
sns.lmplot(data = auto_mobile_data, x = "curb_weight", y="horsepower");

# %%
sns.lmplot(data = auto_mobile_data, x = "curb_weight", y="horsepower", hue="fuel_type", ci=False);

# %%
sns.lmplot(data = auto_mobile_data, x = "curb_weight", y="horsepower", col="fuel_type", ci=False);

# %%
sns.lmplot(data = auto_mobile_data, x = "curb_weight", y="engine_size", col="number_of_doors", ci=False);

# %% [markdown]
# ### Join Plot - (Combines Scatter Plot and Histogram)

# %%
sns.jointplot(data=auto_mobile_data, x="engine_size", y="horsepower");

# %%
sns.jointplot(data=auto_mobile_data, x="engine_size", y="horsepower", kind="hex");

# %%
sns.jointplot(data=auto_mobile_data, x="engine_size", y="horsepower", kind="kde", fill=True);

# %%
sns.jointplot(data=auto_mobile_data, x="engine_size", y="horsepower", kind="reg");

# %% [markdown]
# ### Violin Plot (Distribution of Numerical Variable For Several Groups)

# %%
sns.violinplot(data=auto_mobile_data, x = "horsepower");

# %%
sns.violinplot(data=auto_mobile_data, x = "horsepower", y = "fuel_type", orient="h");

# %%
sns.violinplot(data=auto_mobile_data, x = "horsepower", y = "fuel_type", orient="h", hue="fuel_type");

# %%
sns.violinplot(data=auto_mobile_data, x = "body_style", y = "engine_size", hue="body_style");

# %% [markdown]
# ### Strip PLot (Freq Distribution for small Data set)

# %%
sns.stripplot(data= auto_mobile_data, x = "engine_size");

# %%
plt.figure(figsize=(15,5))
sns.stripplot(data= auto_mobile_data, x = "body_style", y="engine_size");

# %%
plt.figure(figsize=(15,5))
sns.stripplot(data= auto_mobile_data, x = "body_style", y="engine_size", jitter=True);

# %%
sns.stripplot(data= auto_mobile_data, x = "fuel_type", y="engine_size", hue="number_of_doors", jitter=True);

# %% [markdown]
# ### Swarm Plot (Avoids Overlapping and similar tp strip plots)

# %%
sns.swarmplot(data= auto_mobile_data, x = "fuel_type", y="engine_size", hue="number_of_doors", dodge=True);

# %% [markdown]
# ### CatPlot
# - Combination Of Multiple Plots to show relation b/w numerical and one or more categorical data

# %%
sns.catplot(data=auto_mobile_data, x = "body_style", y = "horsepower", hue="fuel_type", kind="point");

# %%
sns.catplot(data=auto_mobile_data, x = "fuel_type", y = "horsepower", hue="number_of_doors", col="drive_wheels", kind="bar");

# %%
sns.catplot(data=auto_mobile_data, x = "fuel_type", y = "engine_size", hue="body_style", col="number_of_doors", kind="box");

# %% [markdown]
# ### Pair Plot
# - Shows Relationship b/w 2 numerical data for each pair of coloumn in data set

# %%
sns.pairplot(data=auto_mobile_data[["normalized_losses", "wheel_base", "curb_weight", "engine_size", "price", "peak_rpm"]]);

# %%
sns.pairplot(data=auto_mobile_data, vars=["wheel_base", "curb_weight", "engine_size", "price"], hue="number_of_doors", corner=True);

# %% [markdown]
# ### Heat Map
# - Correlation Matrix

# %%
sns.heatmap(data=auto_mobile_data[["wheel_base", "curb_weight", "engine_size", "price"]].corr());

# %%
auto_mobile_data[["wheel_base", "curb_weight", "engine_size", "price"]].corr()
# Out:
#              wheel_base  curb_weight  engine_size     price
# wheel_base     1.000000     0.782097     0.572027  0.584642
# curb_weight    0.782097     1.000000     0.849072  0.834415
# engine_size    0.572027     0.849072     1.000000  0.872335
# price          0.584642     0.834415     0.872335  1.000000

# %%
sns.heatmap(data=auto_mobile_data[["wheel_base", "curb_weight", "engine_size", "price"]].corr(), annot=True, cbar=False);

# %% [markdown]
# ## PLOTLY
# - Interactive Visualizations

# %%
# !pip install plotly

# %%
import plotly.express as px

# %% [markdown]
# **Histogram**

# %%
his = px.histogram(auto_mobile_data, x = "price")
his.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Bar Blot**

# %%
bar = px.bar(auto_mobile_data, x = "peak_rpm", y="horsepower")
bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Scatter Plot**

# %%
scatter = px.scatter(auto_mobile_data, x = "price", y = "engine_size")
scatter.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Box with Underlying Data**

# %%
box = px.box(auto_mobile_data, x="fuel_type", y = "horsepower", points="all")
box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **3D Scatter Plot**

# %%
scatter_3D = px.scatter_3d(auto_mobile_data, x="fuel_type", y = "horsepower", z="price", color="fuel_type")
scatter_3D.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Customizing Graphs

# %%
# - plt.xlim(left, right)
# - plt.xlim(left, right)

# - plt.title("")
# - plt.xlabel("")
# - plt.ylabel("")

# - plt.set(style="drakgrid")

# - plt.axis("off")

# - ax.legend([])

#- ax.legend(loc=) - (upper left, upper right, lower left, lower right, center, best)

# %% [markdown]
# ## Practice Quiz

# %% [markdown]
# **Load Data**

# %%
placement_data = pd.read_csv("/content/drive/My Drive/DataAnalytics/Data/Placement_Data.csv")
placement_data.head(3)
# Out:
#   gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0      M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1      M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2      M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
#
#   workex  etest_p specialisation  mba_p  status
# 0     No     55.0         Mkt&HR  58.80  Placed
# 1    Yes     86.5        Mkt&Fin  66.28  Placed
# 2     No     75.0        Mkt&Fin  57.80  Placed

# %%
placement_data.shape
# Out:
# (215, 13)

# %%
placement_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gender          215 non-null    object
#  1   ssc_p           215 non-null    float64
#  2   ssc_b           215 non-null    object
#  3   hsc_p           215 non-null    float64
#  4   hsc_b           215 non-null    object
#  5   hsc_s           215 non-null    object
#  6   degree_p        215 non-null    float64
#  7   degree_t        215 non-null    object
#  8   workex          215 non-null    object
#  9   etest_p         215 non-null    float64
#  10  specialisation  215 non-null    object
#  11  mba_p           215 non-null    float64
#  12  status          215 non-null    object
# dtypes: float64(5), object(8)
# memory usage: 22.0+ KB

# %%
placement_data.describe(include="all").T
# Out:
#                 count unique        top freq       mean        std    min  \
# gender            215      2          M  139        NaN        NaN    NaN
# ssc_p           215.0    NaN        NaN  NaN  67.303395  10.827205  40.89
# ssc_b             215      2    Central  116        NaN        NaN    NaN
# hsc_p           215.0    NaN        NaN  NaN  66.333163  10.897509   37.0
# hsc_b             215      2     Others  131        NaN        NaN    NaN
# hsc_s             215      3   Commerce  113        NaN        NaN    NaN
# degree_p        215.0    NaN        NaN  NaN  66.370186   7.358743   50.0
# degree_t          215      3  Comm&Mgmt  145        NaN        NaN    NaN
# workex            215      2         No  141        NaN        NaN    NaN
# etest_p         215.0    NaN        NaN  NaN  72.100558  13.275956   50.0
# specialisation    215      2    Mkt&Fin  120        NaN        NaN    NaN
# mba_p           215.0    NaN        NaN  NaN  62.278186   5.833385  51.21
# ...

# %%
placement_data[placement_data["status"] == "Placed"].shape
# Out:
# (148, 13)

# %%
sns.histplot(placement_data, x = "etest_p");

# %%
sns.countplot(placement_data, x="hsc_s", hue="status");

# %%
sns.countplot(placement_data, x="hsc_s");

# %%
placement_data.columns
# Out:
# Index(['gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s', 'degree_p',
#        'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p', 'status'],
#       dtype='object')

# %%
num_columns = ["ssc_p", "hsc_p", "degree_p", "etest_p", "mba_p"]
placement_data[num_columns].corr()
# Out:
#              ssc_p     hsc_p  degree_p   etest_p     mba_p
# ssc_p     1.000000  0.511472  0.538404  0.261993  0.388478
# hsc_p     0.511472  1.000000  0.434206  0.245113  0.354823
# degree_p  0.538404  0.434206  1.000000  0.224470  0.402364
# etest_p   0.261993  0.245113  0.224470  1.000000  0.218055
# mba_p     0.388478  0.354823  0.402364  0.218055  1.000000

# %%
sns.heatmap(placement_data[["ssc_p", "hsc_p", "degree_p", "etest_p", "mba_p"]].corr(),annot=True, cbar=False);
# sns.heatmap(data=auto_mobile_data[["wheel_base", "curb_weight", "engine_size", "price"]].corr(), annot=True, cbar=False);

# %%
sns.boxplot(placement_data, x="degree_p", hue="hsc_s");

# %%
sns.lmplot(data = placement_data, x = "ssc_p", y="hsc_p", hue="status", ci=False);

# %%
sns.histplot(data= placement_data,
             x = "degree_p",
             hue = "status",
             kde= True);

# %%
sns.boxplot(data= placement_data,
             x = "ssc_p",
             hue = "status");

# %%
sns.jointplot(placement_data, x="degree_p", y="ssc_p", kind="hex");

# %%
sns.histplot(placement_data, x="etest_p", kde=True);

# %%
sns.boxplot(placement_data, x="etest_p");

# %%
placement_data["etest_p"].max()
# Out:
# 98.0
